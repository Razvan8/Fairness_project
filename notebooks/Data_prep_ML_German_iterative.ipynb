# %% [markdown]
# # Imports

# %%
import sys
# %load_ext autoreload
# %autoreload 2

sys.path.append("../libs/")
from ML_functions import *
from bias_injection_and_fairness import * #This imports data_prep automatically

# %% [markdown]
# # Load and prepare data for this specific dataset (German Credit Dataset)

# %%
X,y=load_German_dataset()


##Tests 
def test1(value):
    if value>=35:
        return 1
    else:
        return 0


p_vary = [np.round(i,2) for i in np.arange(0.2, 1.05, 0.05)] #vary the level of bias injection for one sensitive
p_fixed = [0.25] #keep level of bias injection fixed for a sensitive attribute


###Short data processing for this specific dataset

##Replace with binary for age and make ycolumn: 0 or 1
X=replace_values_with_binary(X,"Attribute9",["A91","A93","A94"])# transform Attribute9 it into gender column

y=replace_values_with_binary(y,y.columns[0],[1])# transform y to col with 0/1 values with 0:bad  1:good 
print(y)

X=apply_function_to_column(df=X,column_name="Attribute13",test_function=test1, new_name="Age_group")

X.rename(columns={'Attribute9': 'Gender'}, inplace=True) #rename gender columns as Gender

## Use the main function that creates and save the biased datasets with the bias injection method
# Out:
# Data loaded successfully
#      class
# 0        1
# 1        0
# 2        1
# 3        1
# 4        0
# ..     ...
# 995      1
# 996      1
# 997      1
# 998      0
# 999      1
#
# [1000 rows x 1 columns]

# %% [markdown]
# # Create and save all the biased datasets for different levels of bias injection.

# %%
create_iterative_german_bias(X=X, unprivileged_class_name1="Age_group", unprivileged_class_name2 = "Gender", unprivileged_class_value1 = 0, unprivileged_class_value2 = 0,
                           y = y, p_range1 = p_vary, p_range2 = p_fixed, verbose = True, dataset_name = 'German_credit_biased') #vary bias in age
create_iterative_german_bias(X=X, unprivileged_class_name1="Age_group", unprivileged_class_name2 = "Gender", unprivileged_class_value1 = 0, unprivileged_class_value2 = 0,
                           y = y, p_range1 = p_fixed, p_range2 = p_vary, verbose = True, dataset_name = 'German_credit_biased') #vary bias in gender
# Out:
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 10.05586592178771% .
# No of positive samples of unprivileged class kept is 72, this means 20.224719101123593 % . It should be close to 71.2
# Initial positive percentage of samples from unprivileged class is 14.24581005586592 % .
# Current percentage of samples from positive unprivileged class is 3.761755485893417% .
# No of positive samples of unprivileged class kept is 24, this means 23.52941176470588 % . It should be close to 25.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.972972972972974% .
# No of positive samples of unprivileged class kept is 96, this means 26.96629213483146 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 16.08108108108108 % .
# Current percentage of samples from positive unprivileged class is 3.2710280373831773% .
# No of positive samples of unprivileged class kept is 21, this means 17.647058823529413 % . It should be close to 29.75
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 16.472114137483786% .
# No of positive samples of unprivileged class kept is 127, this means 35.674157303370784 % . It should be close to 106.8
# Initial positive percentage of samples from unprivileged class is 16.212710765239947 % .
# Current percentage of samples from positive unprivileged class is 5.278592375366569% .
# No of positive samples of unprivileged class kept is 36, this means 28.799999999999997 % . It should be close to 31.25
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 16.795865633074936% .
# No of positive samples of unprivileged class kept is 130, this means 36.51685393258427 % . It should be close to 124.6
# Initial positive percentage of samples from unprivileged class is 15.633074935400519 % .
# Current percentage of samples from positive unprivileged class is 5.087209302325581% .
# No of positive samples of unprivileged class kept is 35, this means 28.92561983471074 % . It should be close to 30.25
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 18.89168765743073% .
# No of positive samples of unprivileged class kept is 150, this means 42.13483146067416 % . It should be close to 142.4
# Initial positive percentage of samples from unprivileged class is 16.876574307304786 % .
# Current percentage of samples from positive unprivileged class is 4.3478260869565215% .
# No of positive samples of unprivileged class kept is 30, this means 22.388059701492537 % . It should be close to 33.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 18.274111675126903% .
# No of positive samples of unprivileged class kept is 144, this means 40.44943820224719 % . It should be close to 160.20000000000002
# Initial positive percentage of samples from unprivileged class is 16.243654822335024 % .
# Current percentage of samples from positive unprivileged class is 4.069767441860465% .
# No of positive samples of unprivileged class kept is 28, this means 21.875 % . It should be close to 32.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 22.689075630252102% .
# No of positive samples of unprivileged class kept is 189, this means 53.08988764044944 % . It should be close to 178.0
# Initial positive percentage of samples from unprivileged class is 18.487394957983195 % .
# Current percentage of samples from positive unprivileged class is 5.694444444444445% .
# No of positive samples of unprivileged class kept is 41, this means 26.623376623376622 % . It should be close to 38.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 23.696682464454977% .
# No of positive samples of unprivileged class kept is 200, this means 56.17977528089888 % . It should be close to 195.8
# Initial positive percentage of samples from unprivileged class is 18.246445497630333 % .
# Current percentage of samples from positive unprivileged class is 5.47945205479452% .
# No of positive samples of unprivileged class kept is 40, this means 25.97402597402597 % . It should be close to 38.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 25.97701149425287% .
# No of positive samples of unprivileged class kept is 226, this means 63.48314606741573 % . It should be close to 213.6
# Initial positive percentage of samples from unprivileged class is 17.70114942528736 % .
# Current percentage of samples from positive unprivileged class is 4.787234042553192% .
# No of positive samples of unprivileged class kept is 36, this means 23.376623376623375 % . It should be close to 38.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 27.149321266968325% .
# No of positive samples of unprivileged class kept is 240, this means 67.41573033707866 % . It should be close to 231.4
# Initial positive percentage of samples from unprivileged class is 18.438914027149323 % .
# Current percentage of samples from positive unprivileged class is 5.751633986928105% .
# No of positive samples of unprivileged class kept is 44, this means 26.993865030674847 % . It should be close to 40.75
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 27.640449438202246% .
# No of positive samples of unprivileged class kept is 246, this means 69.10112359550563 % . It should be close to 249.2
# Initial positive percentage of samples from unprivileged class is 18.53932584269663 % .
# Current percentage of samples from positive unprivileged class is 5.598958333333334% .
# No of positive samples of unprivileged class kept is 43, this means 26.060606060606062 % . It should be close to 41.25
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 27.47747747747748% .
# No of positive samples of unprivileged class kept is 244, this means 68.53932584269663 % . It should be close to 267.0
# Initial positive percentage of samples from unprivileged class is 18.355855855855857 % .
# Current percentage of samples from positive unprivileged class is 5.598958333333334% .
# No of positive samples of unprivileged class kept is 43, this means 26.380368098159508 % . It should be close to 40.75
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 29.617486338797818% .
# No of positive samples of unprivileged class kept is 271, this means 76.12359550561798 % . It should be close to 284.8
# Initial positive percentage of samples from unprivileged class is 19.01639344262295 % .
# Current percentage of samples from positive unprivileged class is 5.242966751918159% .
# No of positive samples of unprivileged class kept is 41, this means 23.563218390804597 % . It should be close to 43.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 31.995776135163673% .
# No of positive samples of unprivileged class kept is 303, this means 85.1123595505618 % . It should be close to 302.59999999999997
# Initial positive percentage of samples from unprivileged class is 19.429778247096095 % .
# Current percentage of samples from positive unprivileged class is 5.452292441140025% .
# No of positive samples of unprivileged class kept is 44, this means 23.91304347826087 % . It should be close to 46.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 33.539731682146545% .
# No of positive samples of unprivileged class kept is 325, this means 91.29213483146067 % . It should be close to 320.40000000000003
# Initial positive percentage of samples from unprivileged class is 19.814241486068113 % .
# Current percentage of samples from positive unprivileged class is 6.722689075630252% .
# No of positive samples of unprivileged class kept is 56, this means 29.166666666666668 % . It should be close to 48.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 34.352701325178394% .
# No of positive samples of unprivileged class kept is 337, this means 94.66292134831461 % . It should be close to 338.2
# Initial positive percentage of samples from unprivileged class is 19.77573904179409 % .
# Current percentage of samples from positive unprivileged class is 6.085918854415275% .
# No of positive samples of unprivileged class kept is 51, this means 26.288659793814436 % . It should be close to 48.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 35.6% .
# No of positive samples of unprivileged class kept is 356, this means 100.0 % . It should be close to 356.0
# Initial positive percentage of samples from unprivileged class is 20.1 % .
# Current percentage of samples from positive unprivileged class is 5.667060212514758% .
# No of positive samples of unprivileged class kept is 48, this means 23.88059701492537 % . It should be close to 50.25
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 11.538461538461538% .
# No of positive samples of unprivileged class kept is 84, this means 23.595505617977526 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.972527472527473 % .
# Current percentage of samples from positive unprivileged class is 2.211690363349131% .
# No of positive samples of unprivileged class kept is 14, this means 12.844036697247708 % . It should be close to 21.8
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 11.78082191780822% .
# No of positive samples of unprivileged class kept is 86, this means 24.15730337078652 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 15.068493150684931 % .
# Current percentage of samples from positive unprivileged class is 4.320987654320987% .
# No of positive samples of unprivileged class kept is 28, this means 25.454545454545453 % . It should be close to 27.5
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.26158038147139% .
# No of positive samples of unprivileged class kept is 90, this means 25.280898876404496 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.168937329700274 % .
# Current percentage of samples from positive unprivileged class is 4.400606980273141% .
# No of positive samples of unprivileged class kept is 29, this means 27.884615384615387 % . It should be close to 31.2
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.618724559023068% .
# No of positive samples of unprivileged class kept is 93, this means 26.12359550561798 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 13.83989145183175 % .
# Current percentage of samples from positive unprivileged class is 4.654654654654655% .
# No of positive samples of unprivileged class kept is 31, this means 30.392156862745097 % . It should be close to 35.699999999999996
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.26158038147139% .
# No of positive samples of unprivileged class kept is 90, this means 25.280898876404496 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.986376021798364 % .
# Current percentage of samples from positive unprivileged class is 6.58682634730539% .
# No of positive samples of unprivileged class kept is 44, this means 40.0 % . It should be close to 44.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.141882673942701% .
# No of positive samples of unprivileged class kept is 89, this means 25.0 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.32469304229195 % .
# Current percentage of samples from positive unprivileged class is 7.100591715976331% .
# No of positive samples of unprivileged class kept is 48, this means 45.714285714285715 % . It should be close to 47.25
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 11.901504787961697% .
# No of positive samples of unprivileged class kept is 87, this means 24.43820224719101 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.500683994528044 % .
# Current percentage of samples from positive unprivileged class is 8.357771260997067% .
# No of positive samples of unprivileged class kept is 57, this means 53.77358490566038 % . It should be close to 53.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.021857923497267% .
# No of positive samples of unprivileged class kept is 88, this means 24.719101123595504 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.207650273224044 % .
# Current percentage of samples from positive unprivileged class is 7.511045655375552% .
# No of positive samples of unprivileged class kept is 51, this means 49.03846153846153 % . It should be close to 57.2
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 11.659807956104252% .
# No of positive samples of unprivileged class kept is 85, this means 23.876404494382022 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.266117969821673 % .
# Current percentage of samples from positive unprivileged class is 10.201149425287356% .
# No of positive samples of unprivileged class kept is 71, this means 68.26923076923077 % . It should be close to 62.4
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 11.049723756906078% .
# No of positive samples of unprivileged class kept is 80, this means 22.47191011235955 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.226519337016574 % .
# Current percentage of samples from positive unprivileged class is 10.130246020260492% .
# No of positive samples of unprivileged class kept is 70, this means 67.96116504854369 % . It should be close to 66.95
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.26158038147139% .
# No of positive samples of unprivileged class kept is 90, this means 25.280898876404496 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.032697547683922 % .
# Current percentage of samples from positive unprivileged class is 10.113960113960115% .
# No of positive samples of unprivileged class kept is 71, this means 68.93203883495146 % . It should be close to 72.1
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.380952380952381% .
# No of positive samples of unprivileged class kept is 91, this means 25.56179775280899 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 15.238095238095239 % .
# Current percentage of samples from positive unprivileged class is 12.745098039215685% .
# No of positive samples of unprivileged class kept is 91, this means 81.25 % . It should be close to 84.0
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 11.294765840220386% .
# No of positive samples of unprivileged class kept is 82, this means 23.03370786516854 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 13.636363636363635 % .
# Current percentage of samples from positive unprivileged class is 11.189801699716714% .
# No of positive samples of unprivileged class kept is 79, this means 79.7979797979798 % . It should be close to 79.2
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 10.926694329183956% .
# No of positive samples of unprivileged class kept is 79, this means 22.191011235955056 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 13.416320885200554 % .
# Current percentage of samples from positive unprivileged class is 11.706629055007053% .
# No of positive samples of unprivileged class kept is 83, this means 85.56701030927834 % . It should be close to 82.45
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 11.538461538461538% .
# No of positive samples of unprivileged class kept is 84, this means 23.595505617977526 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.835164835164836 % .
# Current percentage of samples from positive unprivileged class is 13.528591352859134% .
# No of positive samples of unprivileged class kept is 97, this means 89.81481481481481 % . It should be close to 97.2
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 12.972972972972974% .
# No of positive samples of unprivileged class kept is 96, this means 26.96629213483146 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.72972972972973 % .
# Current percentage of samples from positive unprivileged class is 13.797814207650273% .
# No of positive samples of unprivileged class kept is 101, this means 92.66055045871559 % . It should be close to 103.55
# Dataframes saved in their directory from 'Dataframes' directory.
# Initial positive percentage of samples from unprivileged class is 35.6 % .
# Current percentage of samples from positive unprivileged class is 10.679611650485436% .
# No of positive samples of unprivileged class kept is 77, this means 21.629213483146067 % . It should be close to 89.0
# Initial positive percentage of samples from unprivileged class is 14.285714285714285 % .
# Current percentage of samples from positive unprivileged class is 14.285714285714285% .
# No of positive samples of unprivileged class kept is 103, this means 100.0 % . It should be close to 103.0
# Dataframes saved in their directory from 'Dataframes' directory.

# %% [markdown]
# # Create and save models for every subsampled dataset obtained with bias injection

# %%
create_save_iterative_german_models(p_range1=p_vary, p_range2=p_fixed, dataset_name="German_credit_biased",verbose=True) #for varying age
create_save_iterative_german_models(p_range1=p_fixed, p_range2=p_vary, dataset_name="German_credit_biased",verbose=True) #for varying gender
# Out:
# Best Model Hyperparameters: {'random_state': 1, 'C': 1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.84375
# Best Model Hyperparameters: {'random_state': 1, 'C': 10, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7794117647058824
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8115942028985508
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7681159420289855
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7681159420289855
# Best Model Hyperparameters: {'random_state': 1, 'C': 10, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.75
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.726027397260274
# Best Model Hyperparameters: {'random_state': 1, 'C': 20, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8133333333333334
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7647058823529411
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7662337662337663
# Best Model Hyperparameters: {'random_state': 1, 'C': 10, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7662337662337663
# Best Model Hyperparameters: {'random_state': 1, 'C': 10, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7307692307692307
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7701863354037267
# Best Model Hyperparameters: {'random_state': 1, 'C': 1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7425149700598802
# Best Model Hyperparameters: {'random_state': 1, 'C': 50, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7619047619047619
# Best Model Hyperparameters: {'random_state': 1, 'C': 1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7692307692307693
# Best models saved in 'German_credit_biased' directory from 'ML_models' directory.
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7559055118110236
# Best Model Hyperparameters: {'random_state': 1, 'C': 10, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8106060606060606
# Best Model Hyperparameters: {'random_state': 1, 'C': 1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7744360902255639
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.01, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.753731343283582
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.762962962962963
# Best Model Hyperparameters: {'random_state': 1, 'C': 1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7720588235294118
# Best Model Hyperparameters: {'random_state': 1, 'C': 1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8088235294117647
# Best Model Hyperparameters: {'random_state': 1, 'C': 20, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7769784172661871
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8043478260869565
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7642857142857142
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7202797202797203
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8085106382978723
# Best Model Hyperparameters: {'random_state': 1, 'C': 1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7816901408450704
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.01, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.7902097902097902
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.815068493150685
# Best Model Hyperparameters: {'random_state': 1, 'C': 0.1, 'penalty': 'l2', 'max_iter': 1000}
# Validation Accuracy: 0.8055555555555556
# Best models saved in 'German_credit_biased' directory from 'ML_models' directory.
